# %% [markdown]
# <a href="https://colab.research.google.com/github/TimothyBarao/Research-Projects/blob/main/RunPalmTree_Improve_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Paper title: Geometric properties of PalmTree instruction embeddings
# ## Target IJCNN, deadline: End of January
#
#
# ## **Overview**
# *   Geometry of embeddings
# *   Pairwise correlations
# *   Find which are closer to which
# *   Analog relationship or outlier detection, see how embeddings relate different instructions
# *   Analyze how effective basic block search is
# *   Improve it by encoding pairs, or more instructions at a time
# *   Do deep metric learning to improve distance matching/basic block search \
#
# **Pairwise correlations**
# *   Correlations of the embeddings, plot them on histogram
# *   Relies on inner products between two vectors,
#
# **Analyze**
# *   call, ret, mov, etc. most important instructions in malware analysis
# *   Pick common instructions, look at embeddings see which ones are closer
# *   Prediction "non of embeddings will be close/ will be perpendicular"
# *   Look at the vectors, for constants 0, 1, 2, etc.
#
# **Analog query**
# *   K nearest neighbors
# *   Look at vectors in  each layer, as input goes through, can see performance for analog query
# *   Find vector for king, minus vector for man + woman. find vector closest to this, see if result vector is close to king
# *   Outlier detection, look at each layer
#
# **Plot of embedding norms**
# *   Norm inverserly related to the frequency of tokens
# *   The most frequent tokens had smallest norm in Bert
#
# **For outliers, see accuracy of outliers from layer to layer**
# *   Given sequence, see how it changes through the layers
# *   Look at number of layers in model
#
# **Basic Block Search**
# *   Do analysis, how effective the embeddings to characterize similiarities between basic blocks
# *   Average cosine distance used as similarity
#
# **Possible improvment**
# *   Given a basic block, if encodes one instruction at time, then take average
# *   Problem for instructions that are dependant on others
# *   Figure out how to improve it, possible encod epair of instructions at a time
#
# **Metric learning** "Deep Metric Learning to Rank"
# *   If dataset is available, apply FastAP
# *   See if it improves

# %% [markdown]
# ## Initialize Colab & Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install bert-pytorch
# Out:
# Requirement already satisfied: bert-pytorch in /usr/local/lib/python3.7/dist-packages (0.0.1a4)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from bert-pytorch) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from bert-pytorch) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from bert-pytorch) (4.62.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=0.4.0->bert-pytorch) (3.10.0.2)

# %%
# !pip install pytorch-metric-learning
# Out:
# Requirement already satisfied: pytorch-metric-learning in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (4.62.3)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (1.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (1.19.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (1.0.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from pytorch-metric-learning) (0.11.1+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->pytorch-metric-learning) (3.10.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pytorch-metric-learning) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pytorch-metric-learning) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pytorch-metric-learning) (1.4.1)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->pytorch-metric-learning) (7.1.2)

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/PalmTree-Trained/
# Out:
# /content/drive/.shortcut-targets-by-id/1LMg3kN9NvUURy3zB07RjiMQNzN0TPyMm/PalmTree-Trained

# %% [markdown]
# ## Datasets Used for Intrinsic Evaluation

# %%
import pickle
ground_truth_file = "intrinsic_eval/opcode.pkl"
with open(ground_truth_file, 'rb') as f:
    instruction_set = pickle.load(f)

type(instruction_set)
num_of_ins = 0
for ins in instruction_set:
  print(ins, len(instruction_set[ins]) ,instruction_set[ins])
  num_of_ins += len(instruction_set[ins])
print('number of instructions:' , num_of_ins)
print(type(instruction_set['BINOP']))
# Out:
# MOV 4206 {'mov,byte [ rsi + 0x7 ],al', 'mov,dword [ edi + ebx ],eax', 'mov,rbp,qword [ rcx + 0x58 ]', 'mov,qword [ rbp - 0x338 ],r8', 'mov,rcx,qword [ rsp ]', 'mov,qword [ rbp + 0x10 ],r8', 'mov,dword [ eax + 0x14 ],0x0', 'mov,edx,dword [ ecx ]', 'mov,eax,dword [ rcx ]', 'mov,r14,qword [ rbp + 0x8 ]', 'mov,dword [ ebx + edi ],eax', 'mov,rax,qword [ rbx + 0x70 ]', 'mov,ecx,dword [ ebp + 0x1c ]', 'mov,esi,0x10', 'mov,r10d,dword [ rcx + 0x38 ]', 'mov,esi,0x3e', 'mov,dword [ ebp - 0x7c ],0x0', 'mov,rdx,0x1ffffffffffe0000', 'mov,ecx,dword [ rax ]', 'mov,r12d,0x0', 'mov,qword [ rsp + 0x10 ],0x1', 'mov,al,byte [ ecx + 0x1 ]', 'mov,qword [ r14 ],0x0', 'mov,eax,dword [ esp + 0x8c ]', 'mov,ecx,dword [ esp + 0x30 ]', 'mov,byte [ r12 + rbx ],0x30', 'mov,dword [ ebp - 0x48 ],eax', 'mov,qword [ rdx ],rsi', 'mov,edi,dword [ rbp - 0x370 ]', 'mov,r8,qword [ rbp - 0x370 ]', 'mov,eax,dword [ ebp ]', 'mov,qword [ rbp - 0x310 ],rax', 'mov,r13d,dword [ rsp + 0x150 ]', 'mov,byte [ rdx + rbp ],al', 'mov,r10d,dword [ rsp + 0x10 ]', 'mov,rcx,rdx', 'mov,byte [ rbx + 0x1b ],al', 'mov,qword [ rsp ],rsi', 'mov,qword [ rbp - 0x370 ],rcx', 'mov,al,byte [ ebp - 0xf ]', 'mov,rdi,qword [ rbx + 0x30 ]', 'mov,qword [ rbp - 0x2c8 ],0x0', 'mov,r11,qword [ rbp - 0x330 ]', 'push,string', 'mov,ecx,dword [ esp + 0x8 ]', 'mov,rdi,rsp', 'mov,rbx,rdi', 'mov,dword [ rbp ],r15d', 'mov,r12,qword [ r15 + rax * 8 ]', 'mov,byte [ rbp - 0x348 ],0x0', 'mov,eax,dword [ rsp + 0x18 ]', 'mov,r13d,dword [ rbp + 0x10 ]', 'mov,byte [ rax + rbp ],0x5c', 'mov,byte [ r12 + rbx + 0x2 ],al', 'mov,ecx,dword [ esi ]', 'mov,qword [ rbp - 0x408 ],rsi', 'mov,eax,dword [ edi + ebx * 4 + 0x4 ]', 'mov,dword [ r11 + 0x8 ],ebx', 'mov,byte [ rbp - 0x338 ],0x0', 'mov,qword [ rdi + 0x808 ],r9', 'mov,r12,qword [ rdx + 0x58 ]', 'mov,dword [ r12 ],ebx', 'mov,rdx,qword [ rsp + 0x28 ]', 'mov,edx,dword [ ecx + 0x8 ]', 'mov,byte [ rcx ],0x2e', 'mov,edx,0x40', 'mov,eax,dword [ r8 + 0x10 ]', 'mov,eax,dword [ rsp + 0x98 ]', 'mov,dword [ ebp - 0x40 ],ecx', 'mov,qword [ rsp + 0x50 ],r14', 'mov,qword [ rsi + r8 * 8 ],r9', 'mov,rdi,qword [ rsp + 0x48 ]', 'mov,qword [ rbx + 0x38 ],rax', 'mov,edi,0x58', 'mov,byte [ rdx ],0x5c', 'mov,ebx,0x1ff', 'push,dword [ ebx + 0x1c ]', 'mov,dword [ rsp + 0x30 ],ebp', 'mov,eax,dword [ ebp - 0x8 ]', 'push,dword [ ebp + 0x14 ]', 'mov,eax,dword [ esp + 0x10 ]', 'mov,dword [ eax + 0x18 ],0x0', 'mov,esi,address', 'mov,r14,qword [ rbp ]', 'mov,rcx,qword [ rbp - 0x398 ]', 'mov,rax,qword [ rbp - 0x300 ]', 'mov,dword [ ecx + 0x14 ],eax', 'mov,eax,dword [ rbp - 0x318 ]', 'mov,dword [ rdi ],0xa', 'mov,rbx,rdx', 'mov,ecx,dword [ ebp - 0x10 ]', 'mov,dword [ rbp - 0x400 ],0x1', 'mov,ecx,edi', 'mov,edi,dword [ rsp + 0x30 ]', 'mov,edx,0xb88', 'pop,r15', 'mov,qword [ rbx ],rcx', 'mov,rcx,qword [ rax + 0x10 ]', 'mov,dword [ rsp + 0x40 ],r10d', 'mov,ecx,0x7', 'mov,ebx,dword [ ebp - 0x70 ]', 'mov,dword [ rsp + 0x50 ],edx', 'mov,eax,dword [ rdi + 0x18 ]', 'mov,dword [ ebp - 0x8 ],0x0', 'mov,dword [ r14 ],0x3', 'mov,qword [ rsp + 0x60 ],rcx', 'mov,r8d,dword [ rsp + 0x120 ]', 'mov,byte [ r15 + rbx ],0x25', 'mov,eax,dword [ rsp + 0x58 ]', 'mov,byte [ r14 ],0x6c', 'mov,qword [ r9 ],rax', 'mov,r11,rdx', 'mov,qword [ rsp + 0x8 ],rax', 'mov,rax,qword [ rdi + 0x58 ]', 'mov,eax,dword [ ebp + 0x14 ]', 'mov,r13,rsi', 'mov,qword [ rbp - 0x3b0 ],r8', 'mov,rcx,0x20c49ba5e353f7cf', 'mov,qword [ rbx + 0x8 ],rdi', 'mov,rax,qword [ rbp - 0x130 ]', 'mov,edx,0x8d3', 'mov,eax,dword [ ebp - 0x1c ]', 'mov,rsi,rsp', 'mov,rax,qword [ fs : 0x28 ]', 'mov,dword [ ebp - 0x40 ],edx', 'mov,qword [ rbp - 0x2c8 ],rax', 'mov,rax,qword [ r12 + 0x8 ]', 'mov,dword [ rax + 0x8 ],ebp', 'mov,rcx,qword [ rbp - 0x328 ]', 'mov,qword [ rbp - 0x418 ],rax', 'mov,qword [ r12 + 0x28 ],symbol', 'mov,r12d,address', 'mov,eax,0xb5', 'mov,dword [ rdi ],esi', 'mov,qword [ rbp - 0x3a0 ],rax', 'mov,r11,qword [ rsp + 0x28 ]', 'mov,r9,0xae985bf2cbfc89ed', 'mov,byte [ rbp + 0x48 ],cl', 'mov,byte [ rsp + 0x8 ],0x0', 'mov,rax,qword [ rbp - 0x220 ]', 'mov,edx,dword ...
# BINOP 1743 {'sub,r8,rbp', 'add,qword [ rbp - 0x350 ],rax', 'lea,ebx,[ edx + eax ]', 'imul,r10,r15', 'sub,rsi,r14', 'add,esp,0x150', 'lea,r8,[ rsp + 0x20 ]', 'add,rdx,rdi', 'lea,ebp,[ esp + 0x28 ]', 'add,rdi,qword [ r12 ]', 'add,rax,r13', 'lea,rdi,[ rax + rbp + 0x2 ]', 'lea,r13,[ rax - 0x1 ]', 'and,r9d,address', 'sub,esi,eax', 'lea,edx,[ ecx - 0x1 ]', 'add,eax,0x8', 'lea,r14,[ rax + r12 ]', 'lea,r13,[ rax + 0x7 ]', 'sub,esp,0x90', 'add,rbx,0xff', 'and,esi,ecx', 'lea,rax,[ rsp + 0xf ]', 'add,r12d,0x30', 'and,ebx,0x7', 'lea,rdx,[ r14 + rax ]', 'lea,rsp,[ rbp - 0x28 ]', 'lea,rax,[ rbp - 0x2e8 ]', 'and,r15,rax', 'lea,eax,[ rdx + r13 ]', 'add,r10d,r10d', 'lea,rsi,[ rsp + rax * 4 + 0x18 ]', 'lea,rcx,[ r15 + r15 ]', 'or,edx,0x1', 'imul,eax,ecx,address', 'lea,eax,[ ebp - 0x24 ]', 'lea,rbx,[ rsi - 0x1 ]', 'sub,esp,0x38', 'xor,edx,esi', 'sub,esp,0x2c', 'sub,esp,0x24', 'add,rsi,0x1', 'add,eax,dword [ ebp - 0x60 ]', 'lea,rdx,[ rbx + r14 ]', 'add,rsp,0x158', 'add,rbx,rbx', 'and,r10d,eax', 'and,r8d,0x1', 'add,esp,0x48', 'add,ebp,0x4', 'and,edx,0x80', 'lea,ecx,[ rdi - 0x30 ]', 'sub,eax,0x5b', 'or,esi,edx', 'lea,r14,[ rbx + 0x1 ]', 'lea,rbx,[ r12 + 0x18 ]', 'lea,r13,[ rax + 0x20 ]', 'lea,ebx,[ esp + 0x8c ]', 'sub,r14,rdx', 'or,ebp,0x3ff', 'add,rbx,r15', 'lea,esi,[ eax + edi * 8 ]', 'add,r10,qword [ rbp - 0x3b0 ]', 'and,edi,ebx', 'lea,ecx,[ ebp - 0x8 ]', 'imul,rsi,rbx', 'or,dword [ rbp + 0x10 ],0x20', 'add,r8,rax', 'lea,eax,[ eax + edx * 4 ]', 'sub,eax,symbol', 'lea,rdi,[ rsp + 0x8c ]', 'lea,r12,[ rel  symbol ]', 'sub,esp,0x14', 'lea,eax,[ ebp + 0xc ]', 'lea,r13,[ r12 + 0x1 ]', 'and,ecx,0x2', 'add,eax,0x78', 'add,rdi,0x1', 'and,r13d,dword [ rbp - 0x308 ]', 'lea,eax,[ eax + ebp * 4 ]', 'sub,eax,ecx', 'lea,rsi,[ r13 + rcx - 0x1 ]', 'sub,r8,r9', 'or,ecx,r8d', 'or,r9d,ecx', 'xor,edi,edi', 'and,eax,0x1', 'lea,rdx,[ rbp - 0x2a0 ]', 'or,bl,al', 'lea,r14,[ rsi + 0x1 ]', 'xor,eax,edx', 'lea,rbx,[ rax + rax * 4 ]', 'or,cl,0x92', 'add,edx,dword [ esp + 0x18 ]', 'add,rbx,r8', 'sub,eax,0x41', 'sub,ebp,eax', 'add,edi,ecx', 'add,r11,rcx', 'lea,rdi,[ rax + rbx + 0x1 ]', 'add,dword [ ebp - 0x20 ],0x1', 'and,eax,edi', 'or,r10d,ebp', 'sub,eax,0x99', 'imul,rdi,rbx', 'and,eax,ecx', 'add,edi,dword [ esp + 0x1c ]', 'lea,r14,[ rbp - 0x1f0 ]', 'add,eax,dword [ ecx + 0x28 ]', 'and,rax,0xfffffffffffffff0', 'or,esi,r14d', 'add,r9,qword [ rdi + 0x808 ]', 'and,edx,0x1', 'lea,r13,[ r15 + r14 ]', 'add,esp,0x80', 'lea,rsi,[ rsi + rsi + 0x1 ]', 'add,eax,ebx', 'sub,rbx,r13', 'sub,esp,0x10c', 'add,edx,ebx', 'lea,rdi,[ rsp + 0x8 ]', 'lea,ecx,[ rdx - 0x30 ]', 'lea,rbx,[ r15 + rax ]', 'lea,ebp,[ edx + 0x3 ]', 'add,rax,qword [ r11 ]', 'add,qword [ r15 + 0x18 ],0x1', 'and,esi,eax', 'add,rax,0x10', 'lea,rax,[ rbx + rax * 2 ]', 'or,r8d,esi', 'lea,esi,[ address ]', 'or,esi,dword [ rsp + 0x8 ]', 'and,al,dil', 'lea,eax,[ esp + 0x98 ]', 'sub,ebp,esi', 'lea,rdi,[ r12 + rax ]', 'imul,r9,r13', 'lea,ecx,[ eax + 0x3 ]', 'add,rsi,rsi', 'add,rdi,r8', 'add,dword [ ebp - 0x10 ],0x1', 'sub,rax,rsi', 'or,rax,r12', 'lea,rax,[ rdx + 0x10 ]', 'add,esp,0x34', 'sub,qword [ r12 + 0x18 ],0x1', 'sub,eax,edx', 'imul,eax,edi', 'lea,r14,[ r12 + rbp ]', 'or,dword [ rbp + 0x10 ],0x1', 'and,edi,0x4', 'lea,rax,[ r14 + r14 ]', 'add,edx,0x34', 'sub,esp,0x88', 'add,eax,0x7', 'sub,rsp,0x98', 'lea,rax,[ rdx - address ]', 'add,rsi,r15', 'lea,r12,[ rbp + r14 ]', 'lea,ecx,[ edx + ecx * 4 ]', 'and,r13d,0x1', 'lea,eax,[ rsi + rsi * 4 ]', 'lea,r13,[ rdi + 0x20 ]', 'imul,rax,rax,0x18', 'add,ecx,0x3c', 'add,esp,0xc', 'lea,rdi,[ r12 + 0x10 ]', 'add,rbx,0x4', 'add,rax,rdi', 'add,r13,r13', 'sub,r14,0x1', 'and,rdi,0xfffffffffffffff8', 'or,byte [ r14 ],al', 'or,r9d,edi', 'add,rax,qword [ r15 ]', 'lea,ecx,[ eax + ebp * 4 ]', 'add,rdi,rbp', 'lea,rbx,[ rcx - 0x1 ]', 'add,rax,qword [ rdx + 0x8 ]', 'lea,rdx,[ rax + rbp ]', 'or,ecx,eax', 'add,eax,dword [ ebp - 0x10 ]', 'lea,esi,[ ebp - 0x88 ]', 'lea,rdx,[ rsp + 0x50 ]', 'lea,rax,[ rbx + rax ]', 'lea,eax,[ ebp - 0x6c ]', 'xor,ah,0x80', 'add,r14,qword [ rax + 0x8 ]', 'lea,r12,[ rax + rbp ]', ...
# CALL 25 {'call,eax', 'call,dword [ ebx + edi * 4 - 0x100 ]', 'call,qword [ r15 + 0x30 ]', 'call,r14', 'call,edx', 'call,qword [ r12 + 0x30 ]', 'retn', 'call,qword [ rbp + 0x40 ]', 'call,r9', 'call,rax', 'call,qword [ r12 + 0x8 ]', 'call,rdx', 'call,r15', 'call,qword [ rbp + 0x30 ]', 'call,qword [ r12 + rbx * 8 ]', 'call,dword [ ebx + edi * 4 - 0xf8 ]', 'call,r12', 'call,qword [ rbp + 0x38 ]', 'call,qword [ r13 + 0x30 ]', 'call,dword [ symbol ]', 'call,ecx', 'leave', 'call,qword [ r12 + 0x38 ]', 'call,symbol', 'call,qword [ r13 + 0x38 ]'}
# CMP 1272 {'cmp,dword [ rax ],0x5', 'cmp,r14,address', 'cmp,r13,r11', 'cmp,dword [ ebp - 0x104 ],0x0', 'cmp,dword [ ebp - 0xc ],0x0', 'cmp,dword [ ebp - 0xc ],0xf', 'cmp,qword [ rsp + 0x68 ],0x1', 'cmp,r12,rax', 'cmp,rax,0x6', 'cmp,qword [ r12 + 0x40 ],0x0', 'cmp,dl,0x20', 'cmp,r10,r15', 'test,byte [ ecx + ecx + symbol ],0x88', 'cmp,dword [ r14 ],0x2', 'cmp,rcx,r15', 'cmp,dword [ esp + 0x4 ],0x0', 'cmp,dl,0x61', 'cmp,dword [ rax ],0x22', 'cmp,byte [ rbx + 0x21 ],0x0', 'cmp,r14,0x6', 'cmp,ax,0x1', 'cmp,rdx,rcx', 'cmp,eax,dword [ ebp + 0x20 ]', 'cmp,dword [ rbx + 0x30 ],0x2', 'cmp,r15,symbol', 'cmp,byte [ rax + 0x2 ],0x31', 'cmp,eax,0x54', 'cmp,byte [ rbp + 0x1a ],0x0', 'cmp,r8b,0x3d', 'test,byte [ rbp - 0x370 ],0x4', 'cmp,dl,0x2d', 'cmp,rax,0x9', 'cmp,eax,0x64', 'cmp,edx,0x22', 'cmp,r10b,0x67', 'cmp,r10d,0x2', 'test,r10d,r10d', 'cmp,dl,al', 'cmp,dword [ rbp ],0x9', 'cmp,byte [ r8 + 0x23 ],0x0', 'cmp,dword [ rsp + 0x8 ],0x3e8', 'cmp,dword [ ebp - 0x4 ],0x0', 'test,dword [ rsi + rax * 4 ],edx', 'cmp,dword [ ebp - 0x14 ],eax', 'cmp,rax,rdi', 'cmp,dword [ rbx + 0x30 ],0x0', 'cmp,dword [ rbp - 0x320 ],0x0', 'cmp,r13,0xfffffffffffffffd', 'cmp,byte [ r12 + 0x26 ],0x0', 'cmp,edi,0x3', 'cmp,bl,0x6a', 'cmp,qword [ rax ],0x0', 'cmp,ebx,dword [ esi + 0x8 ]', 'cmp,dword [ eax + 0x24 ],0x0', 'cmp,rax,rcx', 'cmp,eax,dword [ symbol ]', 'cmp,eax,symbol', 'cmp,eax,dword [ ebp - 0x20 ]', 'cmp,dword [ r13 ],0x5', 'cmp,r11d,r10d', 'cmp,byte [ rbx + 0x1e ],0x0', 'cmp,byte [ rbx + rax - 0x1 ],0x2f', 'cmp,qword [ rsp + 0x20 ],rdi', 'cmp,dword [ rsi ],0x4', 'cmp,rax,r15', 'cmp,dword [ rbp - 0x264 ],eax', 'cmp,r8d,address', 'cmp,dl,0x25', 'cmp,r9d,address', 'cmp,ecx,address', 'cmp,dword [ r14 ],0x11', 'cmp,eax,0x82', 'cmp,dword [ rsp + 0x110 ],address', 'cmp,rbx,0x7ff', 'cmp,qword [ rsp + 0x8 ],0xffffffffffffffff', 'cmp,byte [ rsp + 0x4e ],0x0', 'cmp,byte [ r12 + 0x15 ],0x0', 'cmp,dword [ edx + eax * 4 ],0x0', 'cmp,byte [ address ],0x2', 'cmp,esi,0x8', 'cmp,r8,qword [ rbp - 0x358 ]', 'test,byte [ rbp - 0x370 ],0x20', 'cmp,rsi,rdx', 'cmp,dword [ edi + esi ],0x0', 'cmp,byte [ rbp - 0x330 ],0x0', 'cmp,byte [ rbx + 0x14 ],0x1', 'test,dh,0x1', 'cmp,byte [ rsp + 0x4c ],0x0', 'cmp,qword [ rdi + 0x8 ],r9', 'cmp,r8b,dl', 'cmp,byte [ rdx + 0x2 ],0x42', 'cmp,byte [ r12 + 0x14 ],al', 'cmp,dword [ eax + 0x20 ],0x8', 'cmp,al,0x5c', 'cmp,dword [ symbol ],0x0', 'cmp,dword [ r15 ],0x5', 'test,rdi,rdi', 'cmp,byte [ eax ],0x0', 'cmp,byte [ rax - 0x1 ],0x0', 'cmp,qword [ rax + 0x8 ],rdx', 'cmp,edx,0x2f', 'cmp,byte [ r12 ],0x2f', 'cmp,qword [ rbp - 0x330 ],rax', 'cmp,byte [ rsp + 0x4 ],0x0', 'cmp,byte [ rax ],0x43', 'cmp,byte [ rbx + rdx - 0x1 ],0x2f', 'cmp,dl,0x9', 'cmp,byte [ rax + rdx + 0x13 ],0x0', 'cmp,dword [ eax + 0x10 ],0x0', 'cmp,sil,0x25', 'cmp,rcx,rdx', 'cmp,edi,0x8', 'cmp,qword [ rsp ],rax', 'cmp,rax,r11', 'cmp,rbx,qword [ r12 + 0x8 ]', 'cmp,edx,0x24', 'cmp,edx,0x5c', 'cmp,r14d,0x2', 'cmp,eax,0x44', 'cmp,byte [ rbx + 0x28 ],0x0', 'test,r8b,r8b', 'cmp,dword [ ebp - 0x110 ],0x0', 'cmp,dword [ rbp - 0x348 ],0x0', 'cmp,qword [ rsp + 0xd0 ],rax', 'cmp,dword [ ebx + 0x2c ],0x0', 'cmp,dword [ rsp + 0x4 ],ebx', 'cmp,cl,0x53', 'cmp,dword [ eax ],0x0', 'cmp,dword [ ebx + 0x24 ],0x0', 'cmp,al,0x39', 'cmp,dword [ ebp - 0x80 ],0x0', 'test,rsi,rsi', 'test,cl,cl', 'cmp,r8d,0x1', 'cmp,r14d,r13d', 'cmp,sil,0x2d', 'cmp,byte [ rsp + 0x15 ],0x0', 'cmp,rax,rsi', 'cmp,byte [ rax + 0x4 ],0x30', 'cmp,r15,0xfffffffffffffffd', 'cmp,ebx,0x8', 'cmp,eax,0x11', 'cmp,rax,symbol', 'cmp,esi,ecx', 'cmp,dword [ ebp - 0x20 ],0xf', 'test,byte [ rsp + 0x17 ],al', 'cmp,dword [ ebp + 0x24 ],0x0', 'cmp,dword [ rel  symbol ],address', 'cmp,ebp,dword [ ebx ]', 'cmp,qword [ rbp - 0x3d8 ],0x0', 'test,al,al', 'cmp,qword [ rsi - 0x8 ],0x0', 'cmp,byte [ r12 + 0x31 ],0x0', 'cmp,byte [ ebx + 0x38 ],0x2f', 'cmp,byte [ rel  symbol ],0x0', 'cmp,dword [ ebp - 0x1c ],0x3c', 'test,dword [ rsp + 0xf0 ],eax', 'cmp,al,0x9', 'cmp,r10b,0x75', 'cmp,r13d,dword [ rsp + 0x2c ]', 'cmp,ecx,0x1', 'cmp,rbp,string', 'test,byte [ rs ...
# JMP 40 {'jmp,ecx', 'jns,address', 'jmp,dword [ ebx * 4 + symbol ]', 'jbe,string', 'jmp,symbol', 'js,address', 'jbe,address', 'jmp,dword [ edx * 4 + symbol ]', 'jmp,qword [ rbx * 8 + symbol ]', 'jmp,qword [ rel  symbol ]', 'jmp,qword [ r8 * 8 + symbol ]', 'jae,address', 'je,string', 'jmp,qword [ rdx * 8 + symbol ]', 'jg,address', 'jge,address', 'jmp,dword [ address ]', 'jmp,dword [ esi * 4 + symbol ]', 'ja,address', 'jne,string', 'jmp,dword [ eax * 4 + symbol ]', 'jl,address', 'jmp,qword [ rax * 8 + address ]', 'js,string', 'je,address', 'jne,address', 'jb,address', 'jmp,string', 'jmp,dword [ symbol ]', 'jmp,qword [ rcx * 8 + symbol ]', 'jmp,address', 'jmp,qword [ rax * 8 + symbol ]', 'jmp,rax', 'jle,address', 'jmp,eax', 'jmp,qword [ rcx * 8 + address ]', 'jb,string', 'jmp,qword [ rel  address ]', 'jmp,dword [ edi * 4 + symbol ]', 'jmp,qword [ r12 * 8 + symbol ]'}
# SHIFT 153 {'shl,rdx,0x5', 'shl,eax,0x10', 'shr,esi,0x10', 'shl,edi,0x18', 'shl,rax,cl', 'sar,ecx,0x1c', 'shl,r13,0xf', 'shl,eax,0x2', 'sar,r8d,0x1f', 'sar,edx,0x19', 'shr,rax,0x20', 'shr,sil,0x6', 'shl,rcx,0x15', 'shl,r14,0x5', 'shl,r12,0x14', 'sar,edx,0x2', 'shr,ecx,0x3', 'shl,edx,0x3', 'sar,edi,0x1f', 'shr,eax,0x8', 'shl,edx,cl', 'shl,rax,0xa', 'shl,r15,0x9', 'shl,ecx,0x2', 'shr,r9,0x21', 'shl,rdx,0x4', 'shl,rdi,cl', 'shl,eax,0x8', 'shl,rbx,0x5', 'sar,ecx,0xd', 'sar,esi,0xd', 'shl,rdx,cl', 'shr,ebx,0x10', 'shr,r13,0x11', 'sar,esi,0x1c', 'sar,esi,0xc', 'sar,edx,0x16', 'shl,r13,0x9', 'shl,edx,0x8', 'sar,rdx,0x7', 'sar,rsi,0x1', 'sar,edx,0x5', 'shr,r15w,0xe', 'shr,rax,0x3f', 'shr,al,0x6', 'sar,rsi,0x3', 'shr,rdx,0x1', 'sar,edx,0x1', 'sar,rsi,0x3f', 'shl,rbx,0x8', 'sar,esi,0x2', 'shl,rcx,0x4', 'shl,edx,0x10', 'sar,esi,0x6', 'shl,r12,0x9', 'shr,eax,cl', 'shl,rsi,0x5', 'sar,esi,0x12', 'shl,rdi,0x4', 'shr,r9,0x5', 'sar,ebx,0x1f', 'shl,rsi,0x4', 'shl,r13,0x4', 'shl,edi,0x8', 'shl,r15,0x5', 'shl,r13,0x14', 'sar,ecx,0xc', 'sar,esi,0x19', 'sar,eax,0x2', 'shr,rcx,0x1', 'sar,ebp,0x1f', 'sar,r12d,0x1f', 'shl,rcx,0x5', 'shl,rdx,0x3', 'shl,rax,0x4', 'shl,edx,0x2', 'sar,ecx,0x19', 'sar,esi,0x5', 'shl,rax,0x8', 'shl,eax,0x0', 'shr,eax,0x10', 'shr,r13,0xe', 'sar,ecx,0x16', 'sar,ecx,0x1f', 'shl,dword [ esp + 0x10 ],0x1', 'shr,r13,0x17', 'shl,r12,0xf', 'shr,eax,0x1f', 'sar,ecx,0x12', 'shl,edi,0x10', 'shl,rax,0x5', 'shl,eax,0x18', 'sar,esi,0x16', 'shr,rcx,0x8', 'sar,r9d,0x1f', 'shr,edx,0x18', 'shl,r10,0x4', 'shl,dword [ ebp - 0x18 ],0x1', 'shr,edx,0x1f', 'shl,rax,0x9', 'shl,r13,0xa', 'sar,rbp,0x3', 'shr,r12,0x17', 'shl,rsi,0x3', 'shl,r13,0xe', 'shr,r12,0xe', 'shr,r13,0x9', 'shl,rcx,0xc', 'shr,edx,0x8', 'shr,r12,0x11', 'sar,edx,0x6', 'shl,edi,cl', 'shr,al,0x3', 'shl,eax,0x1', 'sar,edx,0xd', 'shl,eax,0x3', 'shl,esi,0x8', 'shl,ebx,0x2', 'shl,qword [ rsp + 0x8 ],0x1', 'shr,r9,0x8', 'shl,ecx,0x18', 'shl,r12,0xe', 'sar,eax,0x1f', 'shr,edx,0x10', 'shl,edx,0x18', 'shr,al,0x5', 'shl,ecx,0x10', 'sar,edx,0xc', 'sar,eax,0x1', 'shl,eax,cl', 'shl,r13,0x5', 'shl,esi,0x10', 'shl,ebx,0x10', 'shl,r15,0xa', 'shr,rax,0x1', 'shr,r12,0x9', 'shr,ebx,0x18', 'shr,ax,0xe', 'shl,rdx,0x6', 'shr,eax,0x1', 'sar,esi,0x1f', 'sar,rdi,0x3f', 'sar,edx,0x1c', 'shl,ecx,0x8', 'shl,rbp,0x8', 'sar,edx,0x12', 'shl,dword [ esp + 0x14 ],0x1', 'shl,rbp,0x4', 'shr,eax,0x18', 'sar,edx,0x1f', 'shr,sil,0x3', 'shl,rbx,0x4', 'shl,ebx,0x8'}
# CSET 44 {'seta,dl', 'sete,byte [ rsp + 0x18 ]', 'setl,cl', 'seta,sil', 'setne,byte [ rsp + 0x29 ]', 'setne,bl', 'setne,al', 'setne,r14b', 'sete,bpl', 'seta,al', 'sete,dil', 'setge,r10b', 'setne,r15b', 'setne,bpl', 'sete,sil', 'sete,byte [ rsp ]', 'sete,r11b', 'setg,cl', 'sete,al', 'setg,bl', 'sete,bl', 'setl,al', 'sete,cl', 'sete,r14b', 'setg,r14b', 'sete,byte [ rsp + 0x8 ]', 'setne,byte [ rbp - 0x301 ]', 'setg,r13b', 'setne,cl', 'sete,byte [ rbp - 0x370 ]', 'sete,r8b', 'sete,r9b', 'sete,r12b', 'setne,byte [ rsp + 0x3 ]', 'setg,al', 'setge,cl', 'sete,r10b', 'setne,r8b', 'setne,r10b', 'setne,byte [ esp + 0xf ]', 'setne,r13b', 'setne,dl', 'sete,dl', 'sete,r13b'}
# CMOV 192 {'cmovb,r12,r8', 'cmovae,r10,rdx', 'cmove,r8,qword [ rbp - 0x3a0 ]', 'cmovne,esi,edx', 'cmovb,r15,r13', 'cmovb,rcx,rsi', 'cmovne,ebx,edx', 'cmovb,r8,r11', 'cmovbe,rdx,rcx', 'cmovne,rdx,qword [ rbp - 0x320 ]', 'cmovbe,rcx,rsi', 'cmove,r14,rax', 'cmovb,r10,r11', 'cmovb,r11,r12', 'cmova,rbx,rax', 'cmova,r14,rax', 'cmovbe,eax,edx', 'cmovb,r8,r10', 'cmovl,ebp,eax', 'cmove,eax,dword [ rsp + 0x48 ]', 'cmovne,r13,r12', 'cmova,rax,rdx', 'cmovbe,r11,rdx', 'cmovb,r15,rsi', 'cmova,rcx,rdx', 'cmovae,rax,rdi', 'cmovae,rax,rcx', 'cmove,r9d,edx', 'cmovae,rax,rsi', 'cmove,rdi,rax', 'cmova,r13,rax', 'cmova,r9,r8', 'cmovb,r11,rsi', 'cmovne,r8,rdx', 'cmova,rdi,rsi', 'cmovb,r11,rax', 'cmove,ecx,eax', 'cmove,edx,ebx', 'cmovbe,r13,rax', 'cmove,eax,ecx', 'cmove,rax,rsi', 'cmovb,rsi,rcx', 'cmove,r12d,eax', 'cmovl,ebx,eax', 'cmovb,rax,r15', 'cmovbe,r15,rcx', 'cmove,eax,edx', 'cmove,eax,r13d', 'cmove,r14d,eax', 'cmovbe,rbx,qword [ rel  symbol ]', 'cmovae,r10,rcx', 'cmovb,r13,rdi', 'cmovne,r12,rbx', 'cmovs,rcx,rax', 'cmovne,r14,rax', 'cmove,r15,rax', 'cmovbe,rax,rdi', 'cmovne,rdi,rbx', 'cmova,rbp,rax', 'cmova,rsi,rcx', 'cmovbe,rax,rdx', 'cmove,r9d,r12d', 'cmovbe,rbp,rax', 'cmovb,rax,r13', 'cmovb,r15,rax', 'cmovne,rax,rsi', 'cmova,r8,r9', 'cmovne,eax,ecx', 'cmovne,ebx,eax', 'cmovne,rbp,rbx', 'cmova,r8,r12', 'cmova,rsi,r15', 'cmova,r11,rdi', 'cmovne,r13,rax', 'cmovbe,rsi,rcx', 'cmovae,eax,edx', 'cmovb,rax,rsi', 'cmovne,r15d,r12d', 'cmovbe,edi,eax', 'cmove,edx,eax', 'cmovbe,r13,qword [ rel  symbol ]', 'cmova,r9,r10', 'cmovb,r12,rax', 'cmova,ecx,edx', 'cmovns,r12,rax', 'cmovae,r9,rdx', 'cmovbe,rax,rsi', 'cmovb,r9,r10', 'cmovb,rdi,rsi', 'cmove,rbp,rax', 'cmovne,esi,ecx', 'cmovb,r15,r12', 'cmovne,rax,rdx', 'cmovne,esi,r9d', 'cmove,edi,eax', 'cmovg,ecx,eax', 'cmovne,r8d,edx', 'cmovbe,rdx,rdi', 'cmovae,r13,rax', 'cmova,rcx,rax', 'cmovg,r14,rbx', 'cmovne,eax,edx', 'cmovb,r8,rdi', 'cmovne,r13d,eax', 'cmovne,ebp,eax', 'cmovne,esi,eax', 'cmovb,r11,rdi', 'cmovb,rax,rcx', 'cmova,rax,r9', 'cmovne,rsi,rax', 'cmovne,r10d,r9d', 'cmove,r14d,ebp', 'cmovbe,r8,rcx', 'cmovne,edx,ecx', 'cmova,rsi,r13', 'cmovne,rax,r15', 'cmovb,r13,r8', 'cmovbe,rcx,rbp', 'cmova,r9,r12', 'cmovb,eax,edx', 'cmovb,rbx,rax', 'cmova,rdi,r11', 'cmovne,esi,ebp', 'cmove,ecx,ebx', 'cmova,r11,r8', 'cmovbe,rdx,rax', 'cmovb,r9,rsi', 'cmove,rbx,rbp', 'cmovae,rsi,rdx', 'cmova,r8,rdi', 'cmove,r13,rax', 'cmove,r15d,eax', 'cmovae,rax,r13', 'cmovb,r13,r14', 'cmova,r9,r11', 'cmovb,rdi,r9', 'cmovb,r10,rdi', 'cmovne,edx,esi', 'cmovne,rbx,rax', 'cmove,r13d,eax', 'cmove,rax,r14', 'cmovb,r15,rdx', 'cmove,r12,rax', 'cmova,rbx,rbp', 'cmova,rax,rsi', 'cmove,rax,qword [ rsp + 0x8 ]', 'cmovne,rax,r13', 'cmovne,ecx,ebp', 'cmova,eax,ecx', 'cmova,r9,rdi', 'cmove,rdi,rcx', 'cmovb,r10,rsi', 'cmovns,rcx,rax', 'cmovb,r15,rdi', 'cmovbe,rdi,rax', 'cmovb,rbx,rdx', 'cmovne,rax,rcx', 'cmovne,rax,qword [ rsp + 0x18 ]', 'cmovne,r15,rax', 'cmovb,r13,rsi', 'cmove,ebp,eax', 'cmova,rdx,r14', 'cmovae,r11,rcx', 'cmove,ebx,edx', 'cmovbe,rax,r12', 'cmovae,rdi,rcx', 'cmovbe,rbx,rax', 'cmova,rdx,rcx', 'cmova,rax,rcx', 'cmovne,eax,ebp', 'cmovb,rdi,r10', 'cmove,rbx,rax', 'cmova,r10,rdi', 'cmova,r8,r11', 'cmovb,r13,rdx', 'cmovb,r8,rsi', 'cmovb,r9,rdi', 'cmovb,r9,r11', 'cmovbe,rax,rbx', 'cmove,ebx,eax', 'cmova,r10,r12', 'cmove,rax,rdx', 'cmove,rax,rdi', 'cmovb,r12,rdi', 'cmova,rdi,rcx', 'cmovb,r13,rbx', 'cmova,r10,r8', 'cmovne,eax,r15d', 'cmovne,r8,qword [ rbp - 0x3a0 ]', 'cmovne,ecx,edx', 'cmovbe,rdi,rdx', 'cmovne,esi,r10d'}
# UNARY 25 {'neg,eax', 'not,r9d', 'inc,eax', 'not,rdx', 'not,esi', 'dec,eax', 'inc,ecx', 'inc,esi', 'dec,esi', 'not,r8d', 'inc,ebp', 'not,rcx', 'not,edi', 'not,rsi', 'not,eax', 'not,edx', 'not,r10d', 'dec,edx', 'inc,edi', 'not,ecx', 'inc,edx', 'not,rax', 'not,r13d', 'not,ebx', 'inc,ebx'}
# FP 3 {'fchs', 'faddp,st1', 'fadd,st1'}
# number of instructions: 7703
# <class 'set'>

# %% [markdown]
# ## Import Libraries and Load the PalmTree Model

# %%
#Import Libraries and Load the PalmTree model
import os
from config import *
from torch import nn
from scipy.ndimage.filters import gaussian_filter1d
import vocab

import random
import time
import matplotlib.pyplot as plt
from sklearn.metrics import pairwise_distances
from multiprocessing.dummy import Pool as ThreadPool
from torch import nn, optim

from torch.autograd import Variable
import torch
import numpy as np
import eval_utils as utils
import re
import pickle
import numpy as np

usable_model = utils.UsableTransformer(model_path="./palmtree/transformer.ep19", vocab_path="./palmtree/vocab")

#Read the opcode.pkl file and initialize offsets for Instruction groups
opcode_group_file = "./intrinsic_eval/opcode.pkl"

with open(opcode_group_file, 'rb') as f:
    instruction_set = pickle.load(f)

instruction_groups = dict()

#print('instruction_set is a',type(instruction_set))
offset = 0
for ins in instruction_set:
  ins_list = instruction_set[ins]
  instruction_groups[ins] = []
  instruction_groups[ins].append(offset) #start_index
  instruction_groups[ins].append(len(ins_list)+offset-1) #end_index
  offset += len(ins_list)
#num_of_ins += len(instruction_set[ins])
#print('number of instructions:' , num_of_ins)


#instruction_groups keeps a mapping of an instruction category(i.e. MOV) and start & end indices in that category
for key, val in instruction_groups.items():
    print(key, val)
# Out:
# Loading Vocab ./palmtree/vocab
# Vocab Size:  6631
# MOV [0, 4205]
# BINOP [4206, 5948]
# CALL [5949, 5973]
# CMP [5974, 7245]
# JMP [7246, 7285]
# SHIFT [7286, 7438]
# CSET [7439, 7482]
# CMOV [7483, 7674]
# UNARY [7675, 7699]
# FP [7700, 7702]

# %% [markdown]
# ## Compute Embeddings and Save to FILE [SKIP if FILE exists]

# %%
#Generate Embeddings for Instructions Grouped by Opcode, and pickle the embeddings [The Time Consuming Step]
#Skip This Block if the 'opcode_instructions_embeddings.pkl' file already EXISTS
embeddings_list = []

for ins in instruction_set:
  ins_list = instruction_set[ins]
  for each_ins in ins_list:
    #Get Embeddings for a single Instruction
    each_ins = each_ins.replace(","," ")
    list_of_ins = []
    list_of_ins.append(each_ins)
    embd_matrix = usable_model.encode(list_of_ins) #have to pass a list here
    embd = embd_matrix.flatten()
    embeddings_list.append(embd) 

#dump the list of embeddings to a pickle file for later use
with open('opcode_instructions_embeddings.pkl', 'wb') as f:
    pickle.dump(embeddings_list, f)


print("# of instructions in embeddings_list", len(embeddings_list))
# Out:
# # of instructions in embeddings_list 7703

# %% [markdown]
# ## Load the Embeddings from pickle file and Analyze

# %%
#Unpickle the embeddings, and check it out 
with open('opcode_instructions_embeddings.pkl', 'rb') as f:
    embeddings_list = pickle.load(f)

# %%
#check the shape of the embeddings 
all_embeddings = np.array(embeddings_list)
print(all_embeddings.shape)
#print('Sample Embedding:')
for i in range(0, 0):
  print(all_embeddings[i])
# Out:
# (7703, 128)

# %% [markdown]
# ## Utility Methods

# %%
#method which can get the instruction from instruction_set
#using the instruction_group key and index'
#Do We Really Need this?
def fetch_instruction(_index):

  for key, val in instruction_groups.items():
    start_index = instruction_groups[key][0]
    end_index = instruction_groups[key][1]
    if(_index>=start_index and _index<=end_index):
      idx = _index-start_index
      size = len(instruction_set[key])
      #print('Group:', key,"Index:", idx,"Size:",size)
      if(idx>=size):
        print("Error!")
        return ""
      return list(instruction_set[key])[idx]


#Testing fetch_instruction(_index) method
ins = fetch_instruction(7250)
print(ins)
# Out:
# jmp,symbol

# %%
#Get the Embeddings for an insruction from the outlier_check_list
#Use Index from outlier_check_list
def GetInstructionEmbedding(embd_matrix, ins_index):
  size = embd_matrix.shape[0]
  if(size <= ins_index):
    print("Wrong Index!")
    return
  else:
    return embd_matrix[ins_index]

# %%
#This function is taken from the PalmTree author's Notebook
def find_outliner(embeddings):
    result = pairwise_distances(embeddings, embeddings, metric='cosine')
    result = result.sum(axis=0) #use min/max in stead of sum
    return np.argmax(result)

# %% [markdown]
# ## Creating Groups of Insturctions set with one outlier

# %%
#Randomly pick two instruction groups
#Pick 4 instructions from one group and 1 instruction from the Other [use dictionary instruction_groups for this purpose]
#put the outlier at the end
def CreateTestSamples(sample_size):
  
  random.seed(time.time())
  result_matrix = []

  while (len(result_matrix) < sample_size):
      outliner_key, inliner_key = random.sample(instruction_groups.keys(), 2)
      outliner_choice = random.randint(instruction_groups[outliner_key][0], instruction_groups[outliner_key][1]) 
      #outliner_ins = fetch_instruction(outliner_key, outliner_choice)
      outlier_check_list = []
      counter = 0
      while len(outlier_check_list) < 4:
          inliner_choice = random.randint(instruction_groups[inliner_key][0], instruction_groups[inliner_key][1])
          #inliner_ins = fetch_instruction(inliner_key, inliner_choice)        
          if inliner_choice not in outlier_check_list: #find a different instruction to insert to the set.
              outlier_check_list.append(inliner_choice)
          else:
              counter = counter+1
          if counter >= 100: #Give up after 100 attempts
              break

      if len(outlier_check_list) < 4:
          # print("fail, choose another outlier")
          continue
      else:
          outlier_check_list.append(outliner_choice)   
          result_matrix.append(outlier_check_list)
      #do this until 50,000 rows are created
  result_matrix = np.array(result_matrix)
  print(result_matrix.shape)
  return result_matrix

# %% [markdown]
# ## Testing Accuracy of PalmTree Model

# %%
#print instructions and check outliers from the result_matrix
def test_accuracy(start, finish, result_matrix, verbose=False):
  #Keep an accuracy score
  total = finish-start
  accurate = 0
  for i in range(start,finish):
    check_embeddings = []
    check_row = result_matrix[i]
    if(verbose == True):
      print('[',end="")
    for j in check_row:
      if(verbose == True):
        print(fetch_instruction(j),end="; ")
      check_embeddings.append(all_embeddings[j])
    if(verbose == True):
      print(']', end='\t')
    result = find_outliner(check_embeddings)
    if(verbose == True):
      print('Outlier is at',result)
    if result == 4:
      accurate+=1

  #Print out accuracy
  accuracy = accurate/total*100
  return accuracy

# %%
#Testing the accuary of PalmTree model's Embeddings to detect outliers
#np.set_printoptions(threshold=np.inf)
sample_size = 50000
start = 0
finish = sample_size
#Do this for 10 Iterations, then take mean and STDev
acc_lst = []
for i in range(10):
  result_matrix = CreateTestSamples(sample_size)
  accuracy = test_accuracy(start, finish, result_matrix, verbose=False)
  acc_lst.append(accuracy)
#print(result_matrix[start:finish])
# Out:
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)

# %%
print(acc_lst)
# Out:
# [69.28999999999999, 68.874, 68.72, 68.894, 68.8, 69.072, 68.84599999999999, 68.96799999999999, 69.178, 68.56]

# %%
#Compute avg and SD
import statistics

avg = statistics.mean(acc_lst)
sd = statistics.pstdev(acc_lst)
print('Avg(%):', avg, 'Std Dev:',sd)
# Out:
# Avg(%): 68.9202 Std Dev: 0.20521686090572425

# %% [markdown]
# ## Deep Metric Learning with Triplet Loss

# %%
# Embedding network with triplet loss training on the 50,000 samples generated
from pytorch_metric_learning import losses, reducers

class Embedding(nn.Module):
  def __init__(self, input_dim, hidden_dim, output_dim):
    super(Embedding, self).__init__()

    self.l1 = nn.Linear(input_dim, hidden_dim)
    self.l2 = nn.Linear(hidden_dim, hidden_dim)
    self.l3 = nn.Linear(hidden_dim, output_dim)
    self.relu = nn.ReLU()

  def forward(self, triplets):

    out = self.l1(triplets)
    out = self.relu(out)
    out = self.l2(out)
    out = self.relu(out)
    out = self.l3(out)

    return out

# Begin training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = Embedding(128, 256, 128).to(device)
learning_rate = .001
reducer = reducers.MeanReducer()
criterion = losses.TripletMarginLoss(1.2, reducer, triplets_per_anchor='all')
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=.9)
epochs = 25
labels = torch.Tensor([0, 0, 0, 0, 1])

train_data = result_matrix[0:500, :]

for epoch in range(epochs):
  
  for i, (p1, p2, p3, p4, outlier) in enumerate(train_data):
    p1 = GetInstructionEmbedding(all_embeddings, p1)
    p2 = GetInstructionEmbedding(all_embeddings, p2)
    p3 = GetInstructionEmbedding(all_embeddings, p3)
    p4 = GetInstructionEmbedding(all_embeddings, p4)
    outlier = GetInstructionEmbedding(all_embeddings, outlier)

    data_embeddings = torch.Tensor([p1, p2, p3, p4, outlier]).to(device)

    embeddings = model(data_embeddings)
    optimizer.zero_grad()
    loss = criterion(embeddings, labels)
    print("Loss iteration {}: {}".format(i, loss))

    loss.backward()
    optimizer.step()
    
#torch.save(model.state_dict(), "/content/drive/MyDrive/Colab Notebooks/PalmTree-Trained/model.pth")
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss iteration 0: 0.0
# Loss iteration 1: 0.0
# Loss iteration 2: 0.0
# Loss iteration 3: 0.0
# Loss iteration 4: 0.0
# Loss iteration 5: 0.0
# Loss iteration 6: 0.0
# Loss iteration 7: 0.0
# Loss iteration 8: 0.0
# Loss iteration 9: 0.004522800445556641
# Loss iteration 10: 0.0
# Loss iteration 11: 0.0
# Loss iteration 12: 0.0
# Loss iteration 13: 0.0
# Loss iteration 14: 0.0
# Loss iteration 15: 0.0
# Loss iteration 16: 0.0
# Loss iteration 17: 0.0
# Loss iteration 18: 0.0
# Loss iteration 19: 0.0
# Loss iteration 20: 0.015308678150177002
# Loss iteration 21: 0.0
# Loss iteration 22: 0.024300336837768555
# Loss iteration 493: 0.0
# Loss iteration 494: 0.0
# Loss iteration 495: 0.0
# Loss iteration 496: 0.0
# Loss iteration 497: 0.0
# Loss iteration 498: 0.0
# Loss iteration 499: 0.0

# %%
# Using all_embeddings to create a list for the new metric learning embeddings
print(np.shape(all_embeddings))
metric_embeddings = np.empty([7703, 128])
with torch.no_grad():
  for i, vector in enumerate(all_embeddings):
    vector = torch.Tensor(vector).to("cuda:0")
    new_embedding = model(vector)
    new_embedding = new_embedding.cpu().numpy()
    metric_embeddings[i] = new_embedding

print(np.shape(metric_embeddings))
# Out:
# (7703, 128)
# (7703, 128)

# %%
#dump the list of newly created embeddings to a pickle file for later use
with open('opcode_instructions_metric_embeddings.pkl', 'wb') as f:
    pickle.dump(metric_embeddings, f)

# %% [markdown]
# ## Load Embeddings Learned by Deep Metric Learning

# %%
#Unpickle the Metric embeddings, and check it out 
with open('opcode_instructions_metric_embeddings.pkl', 'rb') as f:
    all_metric_embeddings = pickle.load(f)

# %%
all_metric_embeddings.shape
# Out:
# (7703, 128)

# %% [markdown]
# ## Testing Accuracy of Metric Learning Model

# %%
#print instructions and check outliers from the result_matrix
#Use the Embeddings learned by Metric Learning Model here
def test_accuracy_metric(start, finish, result_matrix, verbose=False):
  #Keep an accuracy score
  total = finish-start
  accurate = 0
  for i in range(start,finish):
    check_embeddings = []
    check_row = result_matrix[i]
    if(verbose == True):
      print('[',end="")
    for j in check_row:
      if(verbose == True):
        print(fetch_instruction(j),end="; ")
      check_embeddings.append(all_metric_embeddings[j])
    if(verbose == True):
      print(']', end='\t')
    result = find_outliner(check_embeddings)
    if(verbose == True):
      print('Outlier is at',result)
    if result == 4:
      accurate+=1

  #Print out accuracy
  accuracy = accurate/total*100
  return accuracy

# %%
#Use this all_metric_embeddings to recalucate the accuracy on the intrinsic evaluation-- Outlier Detection
#Testing the accuary of Metric Learning Model's Embeddings to detect outliers
#np.set_printoptions(threshold=np.inf)
sample_size = 50000
start = 0
finish = sample_size
#Do this for 10 Iterations, then take mean and STDev
acc_lst = []
for i in range(10):
  result_matrix = CreateTestSamples(sample_size)
  accuracy = test_accuracy_metric(start, finish, result_matrix, verbose=False)
  acc_lst.append(accuracy)
# Out:
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)
# (50000, 5)

# %%
print(acc_lst)
# Out:
# [98.792, 98.792, 98.738, 98.72999999999999, 98.764, 98.748, 98.77, 98.72800000000001, 98.758, 98.74000000000001]

# %%
#Compute avg and SD
import statistics

avg = statistics.mean(acc_lst)
sd = statistics.pstdev(acc_lst)
print('Avg(%):', avg, 'Std Dev:',sd)
# Out:
# Avg(%): 98.756 Std Dev: 0.022271057451319486

# %% [markdown]
# # Further Readings & References
#
# **Papers to read**
# *   Geometry of Bert: http://vigir.missouri.edu/~gdesouza/Research/Conference_CDs/IEEE_WCCI_2020/IJCNN/Papers/N-21493.pdf
# * PalmTree: https://arxiv.org/pdf/2103.03809.pdf
